# %% [markdown]
# <a href="https://colab.research.google.com/github/MauLazcano/manejoNumpy/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Numpy: Análisis numérico eficiente con Python**

# %% [markdown]
# NumPy es una biblioteca de Python que ofrece diversas herramientas y funcionalidades esenciales para la computación científica, incluyendo objetos de matriz multidimensional conocidos como *arrays*, rutinas para operaciones rápidas en matrizes, además de operaciones matemáticas, manipulación de formas, estadística entre otros. Es ampliamente utilizada en áreas como análisis de datos, procesamiento de señales y aprendizaje de máquina.
#
# Para acceder a la documentación de esta biblioteca, puedes hacer clic en el siguiente enlace: https://numpy.org/devdocs/index.html

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
url = '/content/drive/MyDrive/Numpy/apples_ts.csv'
datos = np.loadtxt(url, delimiter = ',', usecols = np.arange(1,88,1))

# %%
datos.ndim # dimensiones
datos.shape # forma
datosT = datos.T # Transponer datos para visualisar de forma mas facil

# %%
datos
# Out:
# array([[  1.2013,   2.2013,   3.2013,   4.2013,   5.2013,   6.2013,
#           7.2013,   8.2013,   9.2013,  10.2013,  11.2013,  12.2013,
#           1.2014,   2.2014,   3.2014,   4.2014,   5.2014,   6.2014,
#           7.2014,   8.2014,   9.2014,  10.2014,  11.2014,  12.2014,
#           1.2015,   2.2015,   3.2015,   4.2015,   5.2015,   6.2015,
#           7.2015,   8.2015,   9.2015,  10.2015,  11.2015,  12.2015,
#           1.2016,   2.2016,   3.2016,   4.2016,   5.2016,   6.2016,
#           7.2016,   8.2016,   9.2016,  10.2016,  11.2016,  12.2016,
#           1.2017,   2.2017,   3.2017,   4.2017,   5.2017,   6.2017,
#           7.2017,   8.2017,   9.2017,  10.2017,  11.2017,  12.2017,
#           1.2018,   2.2018,   3.2018,   4.2018,   5.2018,   6.2018,
#           7.2018,   8.2018,   9.2018,  10.2018,  11.2018,  12.2018,
#           1.2019,   2.2019,   3.2019,   4.2019,   5.2019,   6.2019,
#           7.2019,   8.2019,   9.2019,  10.2019,  11.2019,  12.2019,
# ...

# %% [markdown]
# # Visualización y Selección

# %%
fechas = datosT[:,0]
precios = datosT[:,1:]

# %%
import matplotlib.pyplot as plt
plt.plot(fechas,precios) # Todas las ciudades

# %%
plt.plot(fechas,precios[:,0]) # Solo la primera ciudad

# %%
fechas = np.arange(1,88,1)
plt.plot(fechas,precios[:,0]) # Se sigue la misma secuencia, por lo tanto, se grafíca mejor

# %%
moscu = precios[:,0]
kaliningrado = precios[:,1]
petersburgo = precios[:,2]
krasnodar = precios[:,3]
ekaterimburgo = precios[:,4]
fechas = np.arange(1,88,1)
plt.plot(fechas,kaliningrado)

# %% [markdown]
# # Comparación entre arrays

# %% [markdown]
# Precio de las manzanas en Moscu durante 4 años (2013-2016)

# %%
moscu1 = moscu[0:12] # Primer año
moscu2 = moscu[12:24] # Segundo año
moscu3 = moscu[24:36] # Tercer año
moscu4 = moscu[36:48] # Cuarto año
plt.plot(np.arange(1,13,1), moscu1)
plt.plot(np.arange(1,13,1), moscu2)
plt.plot(np.arange(1,13,1), moscu3)
plt.plot(np.arange(1,13,1), moscu4)
plt.legend(['2013', '2014', '2015', '2016'])

# %%
kaliningrado1 = kaliningrado[0:12] # Primer año
kaliningrado2 = kaliningrado[12:24] # Segundo año
kaliningrado3 = kaliningrado[24:36] # Tercer año
kaliningrado4 = kaliningrado[36:48] # Cuarto año
plt.plot(np.arange(1,13,1), kaliningrado1)
plt.plot(np.arange(1,13,1), kaliningrado2)
plt.plot(np.arange(1,13,1), kaliningrado3)
plt.plot(np.arange(1,13,1), kaliningrado4)
plt.legend(['2013', '2014', '2015', '2016'])

# %%
petersburgo1 = petersburgo[0:12]
petersburgo2 = petersburgo[12:24]
petersburgo3 = petersburgo[24:36]
petersburgo4 = petersburgo[36:48]
plt.plot(np.arange(1,13,1), petersburgo1)
plt.plot(np.arange(1,13,1), petersburgo2)
plt.plot(np.arange(1,13,1), petersburgo3)
plt.plot(np.arange(1,13,1), petersburgo4)
plt.legend(['2013', '2014', '2015', '2016'])

# %%
krasnodar1 = krasnodar[0:12]
krasnodar2 = krasnodar[12:24]
krasnodar3 = krasnodar[24:36]
krasnodar4 = krasnodar[36:48]
plt.plot(np.arange(1,13,1), krasnodar1)
plt.plot(np.arange(1,13,1), krasnodar2)
plt.plot(np.arange(1,13,1), krasnodar3)
plt.plot(np.arange(1,13,1), krasnodar4)
plt.legend(['2013', '2014', '2015', '2016'])

# %%
ekaterimburgo1 = ekaterimburgo[0:12]
ekaterimburgo2 = ekaterimburgo[12:24]
ekaterimburgo3 = ekaterimburgo[24:36]
ekaterimburgo4 = ekaterimburgo[36:48]
plt.plot(np.arange(1,13,1), ekaterimburgo1)
plt.plot(np.arange(1,13,1), ekaterimburgo2)
plt.plot(np.arange(1,13,1), ekaterimburgo3)
plt.plot(np.arange(1,13,1), ekaterimburgo4)
plt.legend(['2013', '2014', '2015', '2016'])

# %%
np.array_equal(moscu1,moscu2) # Comparar si el array es igual
# Out:
# False

# %%
np.allclose(moscu1,moscu2, 5) # Similtud entre el comportamiento de los arrays. El tercer parametro es la variación que puede haber entre uno y otro
# Out:
# True

# %% [markdown]
# Se puede notar cierta similitud entre los números y los arrays con escalares, vectores y matrices en matemáticas.
# ## Escalares:
# Son números simples que utilizamos en operaciones matemáticas básicas como sumas y multiplicaciones.
# Representan una sola cantidad, como la temperatura o el peso.
# Ejemplo: 27 C (temperatura), 70 kg (peso).
# ## Vectores:
# Son estructuras de datos que agrupan múltiples cantidades relacionadas.
# Pueden representar secuencias de valores, como los pesos de boxeadores en una categoría.
# También se utilizan para indicar la posición de un objeto en el espacio mediante coordenadas.
# Ejemplo: (70.0, 72.0, 71.2, 70.5) (pesos de boxeadores), (4, 3) (coordenadas de un punto).
# ## Matrices:
# Son estructuras de datos que organizan múltiples valores relacionados en forma de tabla.
# Pueden representar tablas de datos con filas y columnas.
# También pueden tener más de dos dimensiones, como las matrices 3D, que se utilizan en procesamiento de imágenes, animaciones y modelado matemático.
# Ejemplo: Una tabla con 3 filas y 3 columnas.
# ## Dimensiones:
# Se refiere al número de ejes en los que varía la información.
# Un vector es unidimensional porque varía en una sola dimensión (una secuencia de valores).
# Una matriz 2D es bidimensional porque tiene filas y columnas.
# El número de filas y columnas de una matriz es importante para operaciones como la suma y la multiplicación, ya que las dimensiones deben ser compatibles.

# %% [markdown]
# # Tratamiento de Nan

# %%
promedio = np.mean(moscu)
print(promedio)
# Out:
# 98.79781609195402

# %%
promedio = np.mean(kaliningrado)
print(promedio)
# Out:
# 74.55942528735632

# %% [markdown]
# ## Método .isnan
# Sirve para identificar valores Nan (not a number) dentro de un array.
#
# Se puede usar la interpolacion para remplazar el valor Nan
#
# La interpolacion se refiere a usar un valor anterior y uno pasterior, sumarlos y obtener el promedio para remplazar el valor faltante

# %% [markdown]
# # Diferencia entre arrays

# %%
x = fechas
y = 0.5*x+78 # y = ax + b

# %%
y
# Out:
# array([ 78.5,  79. ,  79.5,  80. ,  80.5,  81. ,  81.5,  82. ,  82.5,
#         83. ,  83.5,  84. ,  84.5,  85. ,  85.5,  86. ,  86.5,  87. ,
#         87.5,  88. ,  88.5,  89. ,  89.5,  90. ,  90.5,  91. ,  91.5,
#         92. ,  92.5,  93. ,  93.5,  94. ,  94.5,  95. ,  95.5,  96. ,
#         96.5,  97. ,  97.5,  98. ,  98.5,  99. ,  99.5, 100. , 100.5,
#        101. , 101.5, 102. , 102.5, 103. , 103.5, 104. , 104.5, 105. ,
#        105.5, 106. , 106.5, 107. , 107.5, 108. , 108.5, 109. , 109.5,
#        110. , 110.5, 111. , 111.5, 112. , 112.5, 113. , 113.5, 114. ,
#        114.5, 115. , 115.5, 116. , 116.5, 117. , 117.5, 118. , 118.5,
#        119. , 119.5, 120. , 120.5, 121. , 121.5])

# %%
plt.plot(fechas, moscu)
plt.plot(x,y)

# %%
valorAbs =np.sqrt(np.sum(np.power(moscu-y, 2)))
print(valorAbs)
# Out:
# 103.53131941591394

# %%
np.linalg.norm(moscu - y) # Normalización
# Out:
# np.float64(103.53131941591394)

# %% [markdown]
# # Regresión lineal

# %%
n = np.size(moscu)
y = moscu
x = fechas
a = (n*np.sum(x*y)- np.sum(x)*np.sum(y)) / (n*np.sum(x**2)- np.sum(x)**2)
b = np.mean(y) - a*np.mean(x)

# %%
print(f'Pendiente = {a}\nInterseccion= {b}')
# Out:
# Pendiente = 0.43520212145512926
# Interseccion= 79.64892274792834

# %%
y = a*x + b
np.linalg.norm(moscu-y)
plt.plot(fechas, moscu)
plt.plot(x,y)
plt.plot(25, a*25+b, '*r') # Precio en el mes 25
plt.plot(75, a*75+b, '*b') # Precio en el mes 75
print(f'Precio en el mes 25 = {round(a*25+b, 2)}')
print(f'Precio en el mes 75 = {round(a*75+b, 2)}')
# Out:
# Precio en el mes 25 = 90.53
# Precio en el mes 75 = 112.29

# %% [markdown]
# # Valores aleatorios

# %%
np.random.randint(40, 100, 100)
# Out:
# array([72, 85, 79, 67, 60, 74, 98, 96, 78, 54, 69, 69, 90, 86, 47, 80, 98,
#        71, 79, 64, 50, 67, 67, 62, 70, 60, 97, 62, 69, 92, 84, 83, 87, 55,
#        81, 85, 45, 99, 82, 48, 47, 74, 67, 82, 78, 62, 98, 88, 55, 53, 58,
#        47, 92, 64, 80, 51, 84, 58, 58, 88, 90, 52, 74, 77, 67, 85, 58, 43,
#        86, 60, 50, 69, 77, 72, 73, 64, 92, 67, 76, 61, 57, 88, 99, 49, 77,
#        75, 65, 83, 80, 53, 87, 50, 61, 93, 61, 46, 93, 82, 84, 52])

# %%
np.random.uniform(0.1, 0.9, 100)
# Out:
# array([0.38885354, 0.55273334, 0.73737262, 0.55533213, 0.6178695 ,
#        0.84102222, 0.32519662, 0.34403752, 0.54583952, 0.15027791,
#        0.52202989, 0.24174131, 0.64539891, 0.60190107, 0.44091582,
#        0.31110054, 0.31506201, 0.85985861, 0.24095417, 0.31504705,
#        0.68079056, 0.31855236, 0.58001561, 0.64204017, 0.88142091,
#        0.5027747 , 0.68887636, 0.68017842, 0.21164759, 0.5354177 ,
#        0.57073712, 0.68999853, 0.34561565, 0.59656968, 0.33889787,
#        0.24363944, 0.63409821, 0.10248707, 0.73636298, 0.78629628,
#        0.24271013, 0.78813834, 0.74659084, 0.71694261, 0.12814549,
#        0.46213089, 0.73821995, 0.49536391, 0.82815245, 0.43070342,
#        0.63754198, 0.6025928 , 0.24675969, 0.82816387, 0.82891427,
#        0.56162131, 0.62821122, 0.44864396, 0.17840877, 0.73956519,
#        0.44811026, 0.53139184, 0.5683017 , 0.10980902, 0.88232922,
#        0.45812876, 0.17986378, 0.3164346 , 0.19613321, 0.524074  ,
# ...

# %%
pendientes = np.random.uniform(0.1, 0.9, 100)
for i in range(100):
  print(np.linalg.norm(moscu - (pendientes[i] * x + b)))
# Out:
# 103.80461317158417
# 123.81938493497194
# 102.03969144634546
# 108.58287975564836
# 111.1041698503867
# 101.99930508013611
# 114.30434067153898
# 102.48369334900993
# 109.14987078614881
# 200.0368382334566
# 103.42933932804648
# 162.2201407389112
# 216.08294403422192
# 213.62273855436274
# 108.02827677868436
# 181.26647116749817
# 102.05347987944316
# 155.99029257375759
# 102.2668890513418
# 116.4001828347658
# 124.15754451590828
# 177.6544777507154
# 102.20204708293471
# 192.76724241151834
# 134.34342885983003
# 113.32509167401923
# 154.1024414965912
# 134.02125252986738
# 104.83982634322973
# 142.8807439862392
# 185.7025727965138
# 174.29778543495343
# 102.69125602120224
# 216.0396738968134
# 109.74637215011708
# 222.66721093993516
# 123.11095965991115
# 189.4465912234181
# 118.47399197744902
# 159.22261437087752
# 102.04110591638914
# 158.06018082557478
# 167.2340347921138
# 105.98812012746608
# 117.05237136972904
# 106.08582393561824
# 102.09280488516684
# 166.03660294796842
# ...

# %%
norma = np.array([])
for i in range(100):
  norma = np.append(norma, np.linalg.norm(moscu - (pendientes[i] * x + b)))
norma
# Out:
# array([103.80461317, 123.81938493, 102.03969145, 108.58287976,
#        111.10416985, 101.99930508, 114.30434067, 102.48369335,
#        109.14987079, 200.03683823, 103.42933933, 162.22014074,
#        216.08294403, 213.62273855, 108.02827678, 181.26647117,
#        102.05347988, 155.99029257, 102.26688905, 116.40018283,
#        124.15754452, 177.65447775, 102.20204708, 192.76724241,
#        134.34342886, 113.32509167, 154.1024415 , 134.02125253,
#        104.83982634, 142.88074399, 185.7025728 , 174.29778543,
#        102.69125602, 216.0396739 , 109.74637215, 222.66721094,
#        123.11095966, 189.44659122, 118.47399198, 159.22261437,
#        102.04110592, 158.06018083, 167.23403479, 105.98812013,
#        117.05237137, 106.08582394, 102.09280489, 166.03660295,
#        164.37367517, 132.2196736 , 233.03969084, 233.52356294,
#        144.3882643 , 111.85899403, 137.95600224, 185.86158856,
#        149.86493278, 127.29248616, 143.51095366, 184.02690242,
# ...

# %%
# Estado de aleatoreidad
np.random.seed(99)
# np.random.uniform(0.1,0.9,5)
norma = np.array([])

for i in range(100):
  norma = np.append(norma, np.linalg.norm(moscu - (pendientes[i] * x + b)))
norma
# Out:
# array([103.80461317, 123.81938493, 102.03969145, 108.58287976,
#        111.10416985, 101.99930508, 114.30434067, 102.48369335,
#        109.14987079, 200.03683823, 103.42933933, 162.22014074,
#        216.08294403, 213.62273855, 108.02827678, 181.26647117,
#        102.05347988, 155.99029257, 102.26688905, 116.40018283,
#        124.15754452, 177.65447775, 102.20204708, 192.76724241,
#        134.34342886, 113.32509167, 154.1024415 , 134.02125253,
#        104.83982634, 142.88074399, 185.7025728 , 174.29778543,
#        102.69125602, 216.0396739 , 109.74637215, 222.66721094,
#        123.11095966, 189.44659122, 118.47399198, 159.22261437,
#        102.04110592, 158.06018083, 167.23403479, 105.98812013,
#        117.05237137, 106.08582394, 102.09280489, 166.03660295,
#        164.37367517, 132.2196736 , 233.03969084, 233.52356294,
#        144.3882643 , 111.85899403, 137.95600224, 185.86158856,
#        149.86493278, 127.29248616, 143.51095366, 184.02690242,
# ...

# %% [markdown]
# # Exportación del archivo generado

# %%
pendientes
norma
datos = np.column_stack([norma,pendientes])
datos
datos.shape
# Out:
# (100, 2)

# %%
np.savetxt('/content/drive/MyDrive/Numpy/normaYpendiente.csv', datos, delimiter = ',')

# %% [markdown]
# # Práctica extra
#
# Continuando con el proyecto de las naranjas/toronjas, ahora debes calcular el coeficiente angular utilizando la generación de números aleatorios. Supongamos que ya conoces el valor de b y que este es igual a 17.
